# %%
'''
Modifications mentioned in the log. Done by Ishita

Original Implementation:

Added code for plotting spiketrain and memb volt(all neurons- sluggish)- 27 March

Version uploaded on ModelDB October 2017.
Author:
Basabdatta Sen Bhattacharya, APT group, School of Computer Science,
University of Manchester, 2017.

If you are using the code,
please cite the original work on the model - details are:

B. Sen-Bhattacharya, T. Serrano-Gotarredona, L. Balassa, A. Bhattacharya,
A.B. Stokes, A. Rowley, I. Sugiarto, S.B. Furber,
"A spiking neural network model of the Lateral Geniculate Nucleus on the
SpiNNaker machine", Frontiers in Neuroscience, vol. 11 (454), 2017.

Free online access:
http://journal.frontiersin.org/article/10.3389/fnins.2017.00454/abstract
'''
# Out:
# '\nModifications mentioned in the log. Done by Ishita\n\nOriginal Implementation:\n\nAdded code for plotting spiketrain and memb volt(all neurons- sluggish)- 27 March\n\nVersion uploaded on ModelDB October 2017.\nAuthor:\nBasabdatta Sen Bhattacharya, APT group, School of Computer Science,\nUniversity of Manchester, 2017.\n\nIf you are using the code,\nplease cite the original work on the model - details are:\n\nB. Sen-Bhattacharya, T. Serrano-Gotarredona, L. Balassa, A. Bhattacharya,\nA.B. Stokes, A. Rowley, I. Sugiarto, S.B. Furber,\n"A spiking neural network model of the Lateral Geniculate Nucleus on the\nSpiNNaker machine", Frontiers in Neuroscience, vol. 11 (454), 2017.\n\nFree online access:\nhttp://journal.frontiersin.org/article/10.3389/fnins.2017.00454/abstract\n'

# %%
import pyNN.spiNNaker as p
import time
from spinn_front_end_common.utilities import globals_variables
from quantities import ms
import neo
import numpy as np
import math
import pandas as pd
# import seaborn as sns

#for plotting
from pyNN.utility.plotting import Figure, Panel, Histogram
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')

# for generating random numbers
from pyNN.random import RandomDistribution, NumpyRNG

# start_time = time.time()
globals_variables.unset_simulator()

# %%
def get_mean_rate(numCells, population):
    firing_rate = []      # format = < neuron_id, rate (spikes/ms) >

    for index in range(0,numCells):
        rate = len(population.segments[0].spiketrains[index])/TotalDuration
        firing_rate.append(rate)
    
    return sum(firing_rate)/len(firing_rate)

def calc_irregularity(segment):
    irregularity = 0
    isi_array = []
    for i in range(len(segment.spiketrains)):
            if(len(segment.spiketrains[i])>2):
                isi_array.append([])
                for j in range(len(segment.spiketrains[i])-1):
                    isi_array[-1].append(segment.spiketrains[i][j+1]-segment.spiketrains[i][j])             
    for i in range(len(isi_array)):
        mean = np.mean(isi_array[i])
        sd = np.std(isi_array[i])
        cv = sd / mean
        irregularity += cv
    irregularity = irregularity / len(segment.spiketrains)
    return irregularity

def print_irregularity():
    print("TCR irregularity: ",calc_irregularity(TCR_spikes.segments[0]))
    print("IN irregularity: ",calc_irregularity(IN_spikes.segments[0]))
    print("TRN irregularity: ",calc_irregularity(TRN_spikes.segments[0]))
    

def calc_synchrony(segment):
    spike_counts = np.zeros(int(TotalDuration/2.0), dtype=int)
    for i in range(len(segment.spiketrains)):
        for j in range(len(segment.spiketrains[i])):
            index = math.floor(segment.spiketrains[i][j] / 2.0)
            spike_counts[index] += 1
    mean = np.mean(spike_counts)
    var = np.std(spike_counts) * np.std(spike_counts)
    synchrony = var / mean
    return synchrony

def print_synchrony():
    print("TCR synchrony: ",calc_synchrony(TCR_spikes.segments[0]))
    print("IN synchrony: ",calc_synchrony(IN_spikes.segments[0]))
    print("TRN synchrony: ",calc_synchrony(TRN_spikes.segments[0]))

# %%
''' Initialising Time and Frequency parameters'''


# total duration of simulation
TotalDuration = int(1000) #2000.0

# # time-step of model equation solver
# time_resol = 0.1
# TimeInt = 1.0 / time_resol

# this is in ms.
Duration_Inp = int(1000) #1900.0

# 50 ms at both start and end are disregarded to avoid transients
Start_Inp = int(0) #50.0
End_Inp = int(Start_Inp + Duration_Inp)

Rate_Inp = int(22) #10
Inp_isi = int(1000 / Rate_Inp)

# %%
''' Initialising Model connectivity parameters'''

intra_pop_delay = RandomDistribution('uniform', (1,3), rng=NumpyRNG(seed=85520))
intra_nucleus_delay = RandomDistribution('uniform', (1,3), rng=NumpyRNG(seed=85521))
inter_nucleus_delay = RandomDistribution('uniform', (1,3), rng=NumpyRNG(seed=85522))
inter_pop_delay = RandomDistribution('uniform', (1,3), rng=NumpyRNG(seed=85523))
input_delay = inter_pop_delay

# # input_delay is the delay of the spike source hitting the neuronal populations
# # inter_pop_delay is the delay of spike communication between the different
# # populations of the model

# probabilities
p_trn2trn = 0.15
p_in2tcr = 0.1545 #0.232 
p_in2in = 0.236
p_tcr2trn = 0.35
p_trn2tcr = 0.1545 #0.07
p_ret2tcr = 0.07
p_ret2in = 0.47

# weights
w_trn2trn = 1.0 #0.06 #1
w_in2tcr = 0.1 #2
w_in2in = 0.35 #2
w_tcr2trn = 0.115 #0.01 #2 #0.2 and 0.3 give best value -> 0.25
w_trn2tcr = 0.03 #2
w_ret2tcr = 0.275 #0.35 #0.1 #1
w_ret2in = 0.275 #0.35 #0.1 #1

# %%
''' Initialising Izhikevich spiking neuron model parameters.
We have used the conductance-based model here.'''

# Tonic mode parameters
tcr_a_tonic = 0.02
tcr_b_tonic = 0.2
tcr_c_tonic = -65.0
tcr_d_tonic = 6.0
tcr_v_init_tonic = RandomDistribution('uniform', (-63.0,-67.0), rng=NumpyRNG(seed=85520)) #-65.0

in_a_tonic = 0.1
in_b_tonic = 0.2
in_c_tonic = -65.0
in_d_tonic = 6.0
in_v_init_tonic = RandomDistribution('uniform', (-68.0,-72.0), rng=NumpyRNG(seed=85521)) #-70.0

trn_a_tonic = 0.02
trn_b_tonic = 0.2
trn_c_tonic = -65.0
trn_d_tonic = 6.0
trn_v_init_tonic = RandomDistribution('uniform', (-73.0,-77.0), rng=NumpyRNG(seed=85522)) #-75.0

tcr_a = tcr_a_tonic
tcr_b = tcr_b_tonic
tcr_c = tcr_c_tonic
tcr_d = tcr_d_tonic
tcr_v_init = tcr_v_init_tonic


in_a = in_a_tonic
in_b = in_b_tonic
in_c = in_c_tonic
in_d = in_d_tonic
in_v_init = in_v_init_tonic


trn_a = trn_a_tonic
trn_b = trn_b_tonic
trn_c = trn_c_tonic
trn_d = trn_d_tonic
trn_v_init = trn_v_init_tonic


tcr_u_init = RandomDistribution('uniform', (-15.0,-11.0), rng=NumpyRNG(seed=85522))#-13.0 #tcr_b * tcr_v_init
in_u_init = RandomDistribution('uniform', (-16.0,-12.0), rng=NumpyRNG(seed=85522))#-14.0 #in_b * in_v_init
trn_u_init = RandomDistribution('uniform', (-17.0,-13.0), rng=NumpyRNG(seed=85522))#-15.0 #trn_b * trn_v_init

# a constant DC bias current; this is used here for testing the RS and FS
# characteristics of IZK neurons
current_Pulse = RandomDistribution('poisson', lambda_ = 3.0, rng=NumpyRNG(seed=85524)) #5 

# excitatory input time constant
tau_ex = 6.0 

# inhibitory input time constant
tau_inh = 4.0 

# reversal potentials
e_rev_ex = 0.0
e_rev_inh = -80.0

# %%
'''Starting the SpiNNaker Simulator'''
p.setup(timestep=0.1)
## set number of neurons per core to 50, for the spike source to avoid clogging
##p.set_number_of_neurons_per_core(p.SpikeSourceArray, 50)

'''Defining each cell type as dictionary'''

# THALAMOCORTICAL RELAY CELLS (TCR)
TCR_cell_params = {'a': tcr_a_tonic, 'b': tcr_b, 'c': tcr_c, 'd': tcr_d,
                   'v': tcr_v_init, 'u': tcr_u_init,
                   'tau_syn_E': tau_ex, 'tau_syn_I': tau_inh,
                   'i_offset': current_Pulse, 'e_rev_E': e_rev_ex, 'e_rev_I': e_rev_inh
                   }

# THALAMIC INTERNEURONS (IN)
IN_cell_params = {'a': in_a, 'b': in_b, 'c': in_c, 'd': in_d,
                  'v': in_v_init, 'u': in_u_init,
                  'tau_syn_E': tau_ex, 'tau_syn_I': tau_inh,
                  'i_offset': current_Pulse, 'e_rev_E': e_rev_ex, 'e_rev_I': e_rev_inh
                  }

# THALAMIC RETICULAR NUCLEUS (TRN)
TRN_cell_params = {'a': trn_a, 'b': trn_b, 'c': trn_c, 'd': trn_d,
                   'v': trn_v_init, 'u': trn_u_init,
                   'tau_syn_E': tau_ex, 'tau_syn_I': tau_inh,
                   'i_offset': current_Pulse, 'e_rev_E': e_rev_ex, 'e_rev_I': e_rev_inh
                   }

'''Creating populations of each cell type'''
scale_fact = 10
NumCellsTCR = 8*scale_fact
NumCellsIN = 2*scale_fact
NumCellsTRN = 4*scale_fact
TCR_pop = p.Population(
    NumCellsTCR, p.extra_models.Izhikevich_cond, TCR_cell_params, label='TCR_pop')
IN_pop = p.Population(
    NumCellsIN, p.extra_models.Izhikevich_cond, IN_cell_params, label='IN_pop')
TRN_pop = p.Population(
    NumCellsTRN, p.extra_models.Izhikevich_cond, TRN_cell_params, label='TRN_pop')
# Out:
# 2020-03-19 17:05:41 INFO: Read cfg files: /home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/spinnaker.cfg, /home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/spynnaker.cfg, /home/jovyan/.spynnaker.cfg
# 2020-03-19 17:05:41 INFO: Will search these locations for binaries: /home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/common_model_binaries : /home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/model_binaries
# 2020-03-19 17:05:41 WARNING: /home/jovyan/test_codes/15 Jan - Synchrony and Irregularity/reports has 45 old reports that have not been closed
# 2020-03-19 17:05:41 WARNING: A timestep was entered that has forced sPyNNaker to automatically slow the simulation down from real time by a factor of 10. To remove this automatic behaviour, please enter a timescaleFactor value in your .spynnaker.cfg
# 2020-03-19 17:05:41 INFO: Setting time scale factor to 10.
# 2020-03-19 17:05:41 INFO: Setting machine time step to 100 micro-seconds.
# 2020-03-19 17:05:41 WARNING: Formal PyNN specifies that v should be set using initial_values not cell_params
# 2020-03-19 17:05:41 WARNING: Formal PyNN specifies that u should be set using initial_values not cell_params
# 2020-03-19 17:05:41 WARNING: Formal PyNN specifies that v should be set using initial_values not cell_params
# 2020-03-19 17:05:41 WARNING: Formal PyNN specifies that u should be set using initial_values not cell_params
# 2020-03-19 17:05:41 WARNING: Formal PyNN specifies that v should be set using initial_values not cell_params
# 2020-03-19 17:05:41 WARNING: Formal PyNN specifies that u should be set using initial_values not cell_params
# ['/home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/spinnaker.cfg', '/home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/spynnaker.cfg', '/home/jovyan/.spynnaker.cfg']

# %%
''' Poisson input for TCR'''

spike_source_TCR = p.Population(
    NumCellsTCR, p.SpikeSourcePoisson(rate=10, start=Start_Inp, duration=Duration_Inp),
    label='spike_source_TCR')

''' Poisson input for IN'''

spike_source_IN = p.Population(
    NumCellsIN, p.SpikeSourcePoisson(rate=10, start=Start_Inp, duration=Duration_Inp),
    label='spike_source_IN')

'''Poisson Source to TCR population projections'''
Proj0 = p.Projection(
    spike_source_TCR, TCR_pop, p.OneToOneConnector(),
    p.StaticSynapse(weight=w_ret2tcr, delay=input_delay),
    receptor_type='excitatory')


'''Poisson Source2IN'''
Proj1 = p.Projection(
    spike_source_IN, IN_pop, p.OneToOneConnector(),
    p.StaticSynapse(weight=w_ret2in, delay=input_delay),
    receptor_type='excitatory')


'''TCR2TRN'''
Proj2 = p.Projection(
    TCR_pop, TRN_pop, p.FixedProbabilityConnector(p_connect=p_tcr2trn),
    p.StaticSynapse(weight=w_tcr2trn, delay=inter_nucleus_delay),
    receptor_type='excitatory')


'''TRN2TCR'''
Proj3 = p.Projection(
    TRN_pop, TCR_pop, p.FixedProbabilityConnector(p_connect=p_trn2tcr),
    p.StaticSynapse(weight=w_trn2tcr, delay=inter_nucleus_delay),
    receptor_type='inhibitory')


'''TRN2TRN'''
Proj4 = p.Projection(
    TRN_pop, TRN_pop, p.FixedProbabilityConnector(p_connect=p_trn2trn),
    p.StaticSynapse(weight=w_trn2trn, delay=intra_pop_delay),
    receptor_type='inhibitory')


'''IN2TCR'''
Proj5 = p.Projection(
    IN_pop, TCR_pop, p.FixedProbabilityConnector(p_connect=p_in2tcr),
    p.StaticSynapse(weight=w_in2tcr, delay=intra_nucleus_delay),
    receptor_type='inhibitory')


'''IN2IN'''
Proj6 = p.Projection(
    IN_pop, IN_pop, p.FixedProbabilityConnector(p_connect=p_in2in),
    p.StaticSynapse(weight=w_in2in, delay=intra_pop_delay),
    receptor_type='inhibitory')

''' Recording simulation data'''

# recording the spikes and voltage
spike_source_TCR.record("spikes")
spike_source_IN.record("spikes")
# spike_source_periodic_TCR.record("spikes")
# spike_source_periodic_IN.record("spikes")
TCR_pop.record(("spikes", "v", "gsyn_exc", "gsyn_inh"))
IN_pop.record(("spikes", "v", "gsyn_exc", "gsyn_inh"))
TRN_pop.record(("spikes", "v", "gsyn_exc", "gsyn_inh"))

# %%
p.run(TotalDuration)
# Out:
# 2020-03-19 17:05:41 INFO: Starting execution process
# 2020-03-19 17:05:41 INFO: Simulating for 10000 0.1ms timesteps using a hardware timestep of 10us
# 2020-03-19 17:05:47 INFO: Time 0:00:05.581096 taken by SpallocMaxMachineGenerator
# Pre allocating resources for Extra Monitor support vertices
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:02 INFO: Time 0:00:15.027686 taken by PreAllocateResourcesForExtraMonitorSupport
# Partitioning graph vertices
# |0%                          50%                         100%|
#  ============================================================
# Partitioning graph edges
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:12 INFO: Time 0:00:10.245322 taken by PartitionAndPlacePartitioner
# Created spalloc job 5316430
# 2020-03-19 17:06:12 INFO: Created spalloc job 5316430
# Waiting for board power commands to complete.
# 2020-03-19 17:06:12 INFO: Waiting for board power commands to complete.
# 2020-03-19 17:06:17 INFO: Time 0:00:05.053280 taken by SpallocAllocator
# 2020-03-19 17:06:17 INFO: Creating transceiver for 10.11.193.65
# 2020-03-19 17:06:17 INFO: Working out if machine is booted
# 2020-03-19 17:06:21 INFO: Attempting to boot machine
# 2020-03-19 17:06:27 INFO: Found board with version [Version: SC&MP 3.2.5 at SpiNNaker:0:0:0 (built Thu Aug  1 08:15:06 2019)]
# 2020-03-19 17:06:27 INFO: Machine communication successful
# 2020-03-19 17:06:27 INFO: Detected a machine on IP address 10.11.193.65 which has 854 cores and 120.0 links
# 2020-03-19 17:06:27 INFO: Time 0:00:09.661068 taken by MachineGenerator
# Generating partitioner report
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:27 INFO: Time 0:00:00.042533 taken by PartitionerReport
# 2020-03-19 17:06:27 INFO: Time 0:00:00.001617 taken by NetworkSpecificationReport
# Allocating virtual identifiers
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:27 INFO: Time 0:00:00.093889 taken by MallocBasedChipIDAllocator
# Inserting extra monitors into graphs
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:27 INFO: Time 0:00:00.063897 taken by InsertExtraMonitorVerticesToGraphs
# Writing the board chip report
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:27 INFO: Time 0:00:00.023678 taken by BoardChipReport
# Filtering edges
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:27 INFO: Time 0:00:00.090150 taken by GraphEdgeFilter
# Placing graph vertices
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:27 INFO: Time 0:00:00.096931 taken by OneToOnePlacer
# Inserting edges between vertices which require FR speed up functionality.
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:27 INFO: Time 0:00:00.103279 taken by InsertEdgesToExtraMonitorFunctionality
# Generating routing tables for data in system processes
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:27 INFO: Time 0:00:00.023400 taken by SystemMulticastRoutingGenerator
# Generating fixed router routes
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:27 INFO: Time 0:00:00.021886 taken by FixedRouteRouter
# Generating placement report
# |0%                          50%                         100%|
#  ============================================================
# Generating placement by core report
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:28 INFO: Time 0:00:00.360511 taken by PlacerReportWithApplicationGraph
# Routing
# |0%                          50%                         100%|
#  ============================================================
#
# 2020-03-19 17:06:28 INFO: Time 0:00:00.203776 taken by NerRoute
# Discovering tags
# |0%                          50%                         100%|
#  ============================================================
# Allocating tags
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:28 INFO: Time 0:00:00.195150 taken by BasicTagAllocator
# Reporting Tags
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:28 INFO: Time 0:00:00.032439 taken by TagReport
# Getting number of keys required by each edge using application graph
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:28 INFO: Time 0:00:00.270318 taken by EdgeToNKeysMapper
# Getting constraints for application graph
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:29 INFO: Time 0:00:00.274941 taken by ProcessPartitionConstraints
# Allocating routing keys
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:29 INFO: Time 0:00:00.045569 taken by MallocBasedRoutingInfoAllocator
# Generating Routing info report
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:29 INFO: Time 0:00:00.286306 taken by routingInfoReports
# Generating routing tables
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:29 INFO: Time 0:00:00.241003 taken by BasicRoutingTableGenerator
# Finding executable start types
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:30 INFO: Time 0:00:00.340139 taken by LocateExecutableStartType
# Initialising buffers
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:30 INFO: Time 0:00:00.324144 taken by BufferManagerCreator
# Generating data specifications
# |0%                          50%                         100%|
#  ============================================================
# 2020-03-19 17:06:30 ERROR: Error when calling spynnaker.pyNN.overridden_pacman_functions.spynnaker_data_specification_writer.SpynnakerDataSpecificationWriter.__call__ with inputs dict_keys(['placements', 'hostname', 'report_default_directory', 'write_text_specs', 'machine', 'data_n_timesteps', 'graph_mapper'])
# 2020-03-19 17:06:30 ERROR: Error when closing Notifications
# Traceback (most recent call last):
#   File "/home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/abstract_spinnaker_base.py", line 1147, in _run_algorithms
#     executor.execute_mapping()
#   File "/home/jovyan/sPyNNakerGit/PACMAN/pacman/executor/pacman_algorithm_executor.py", line 636, in execute_mapping
#     self.__execute_mapping()
#   File "/home/jovyan/sPyNNakerGit/PACMAN/pacman/executor/pacman_algorithm_executor.py", line 652, in __execute_mapping
#     results = algorithm.call(self._internal_type_mapping)
#   File "/home/jovyan/sPyNNakerGit/PACMAN/pacman/executor/algorithm_classes/abstract_python_algorithm.py", line 77, in call
#     results = self.call_python(method_inputs)
#   File "/home/jovyan/sPyNNakerGit/PACMAN/pacman/executor/algorithm_classes/python_class_algorithm.py", line 89, in call_python
#     return method(**inputs)
#   File "/home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/overridden_pacman_functions/spynnaker_data_specification_writer.py", line 49, in __call__
#     placement_order)
#   File "/home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/interface_functions/graph_data_specification_writer.py", line 107, in __call__
#     placement, associated_vertex, targets, data_n_timesteps)
#   File "/home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/interface_functions/graph_data_specification_writer.py", line 138, in __generate_data_spec_for_vertices
#     vertex.generate_data_specification(spec, pl)
#   File "/home/jovyan/sPyNNakerGit/PACMAN/pacman/executor/injection_decorator.py", line 144, in wrapper
#     return wrapped_method(obj, *args, **new_args)
#   File "/home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/models/neuron/abstract_population_vertex.py", line 486, in generate_data_specification
#     spec, key, vertex_slice, machine_time_step, time_scale_factor)
#   File "/home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/models/neuron/abstract_population_vertex.py", line 391, in _write_neuron_parameters
#     self._parameters, self._state_variables, vertex_slice)
#   File "/home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/models/neuron/implementations/neuron_impl_standard.py", line 171, in get_data
#     for component in self.__components
#   File "/home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/models/neuron/implementations/neuron_impl_standard.py", line 171, in <listcomp>
#     for component in self.__components
#   File "/home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/models/neuron/neuron_models/abstract_neuron_model.py", line 82, in get_data
#     parameters, state_variables, vertex_slice)
#   File "/home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/models/neuron/implementations/abstract_standard_neuron_component.py", line 116, in get_data
#     values, vertex_slice.lo_atom, vertex_slice.n_atoms)
#   File "/home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/models/neuron/implementations/struct.py", line 103, in get_data
#     data_value = convert_to(value, data_type)
#   File "/home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/utilities/utility_calls.py", line 105, in convert_to
#     return numpy.round(data_type.encode_as_int(value)).astype(
#   File "/home/jovyan/sPyNNakerGit/DataSpecification/data_specification/enums/data_type.py", line 391, in encode_as_int
#     if not (self._min <= value <= self._max):
# TypeError: argument must be an integer
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/abstract_spinnaker_base.py", line 2511, in _shutdown
#     if "NotificationInterface" in self._last_run_outputs:
# TypeError: argument of type 'NoneType' is not iterable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-df0bb75c7d05> in <module>
# ----> 1 p.run(TotalDuration)
#
# ~/sPyNNakerGit/sPyNNaker8/spynnaker8/__init__.py in run(simtime, callbacks)
#     683     if not globals_variables.has_simulator():
#     684         raise ConfigurationException(FAILED_STATE_MSG)
# --> 685     return __pynn["run"](simtime, callbacks=callbacks)
#     686
#     687
#
# ~/sPyNNakerGit/lib/python3.6/site-packages/PyNN-0.9.4-py3.6.egg/pyNN/common/control.py in run(simtime, callbacks)
#     109         the initial conditions (time ``t = 0``), use the ``reset()`` function.
#     110         """
# --> 111         return run_until(simulator.state.t + simtime, callbacks)
#     112     return run, run_until
#     113
#
# ~/sPyNNakerGit/lib/python3.6/site-packages/PyNN-0.9.4-py3.6.egg/pyNN/common/control.py in run_until(time_point, callbacks)
#      91                         for callback in active_callbacks)
#      92         else:
# ---> 93             simulator.state.run_until(time_point)
#      94         return simulator.state.t
#      95
#
# ~/sPyNNakerGit/sPyNNaker8/spynnaker8/spinnaker.py in run_until(self, tstop)
#     121         """
#     122         # Build data
# --> 123         self._run_wait(tstop - self.t)
#     124
#     125     def clear(self):
#
# ~/sPyNNakerGit/sPyNNaker8/spynnaker8/spinnaker.py in _run_wait(self, duration_ms)
#     151         """
#     152
# --> 153         super(SpiNNaker, self).run(duration_ms)
#     154
#     155     @property
#
# ~/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/abstract_spinnaker_common.py in run(self, run_time)
#     344         for projection in self._projections:
#     345             projection._clear_cache()
# --> 346         super(AbstractSpiNNakerCommon, self).run(run_time)
#     347
#     348     @staticmethod
#
# ~/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/abstract_spinnaker_base.py in run(self, run_time)
#     756         :param run_time: the run duration in milliseconds.
#     757         """
# --> 758         self._run(run_time)
#     759
#     760     def _build_graphs_for_usage(self):
#
# ~/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/abstract_spinnaker_base.py in _run(self, run_time, run_until_complete)
#     958         # been changed, generate and load the data
#     959         if not self._has_ran or graph_changed or data_changed:
# --> 960             self._do_data_generation(self._max_run_time_steps)
#     961
#     962             # If we are using a virtual board, don't load
#
# ~/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/abstract_spinnaker_base.py in _do_data_generation(self, n_machine_time_steps)
#    1732
#    1733         executor = self._run_algorithms(
# -> 1734             inputs, algorithms, outputs, tokens, [], "data_generation")
#    1735         self._mapping_outputs = executor.get_items()
#    1736         self._mapping_tokens = executor.get_completed_tokens()
#
# ~/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/abstract_spinnaker_base.py in _run_algorithms(self, inputs, algorithms, outputs, tokens, required_tokens, provenance_name, optional_algorithms)
#    1157             except Exception:
#    1158                 logger.warning("problem when shutting down", exc_info=True)
# -> 1159             reraise(*exc_info)
#    1160
#    1161     def _get_machine(self, total_run_time=0.0, n_machine_time_steps=None):
#
# ~/sPyNNakerGit/lib/python3.6/site-packages/six-1.13.0-py3.6.egg/six.py in reraise(tp, value, tb)
#     694             if value.__traceback__ is not tb:
#     695                 raise value.with_traceback(tb)
# --> 696             raise value
#     697         finally:
#     698             value = None
#
# ~/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/abstract_spinnaker_base.py in _run_algorithms(self, inputs, algorithms, outputs, tokens, required_tokens, provenance_name, optional_algorithms)
#    1145
#    1146         try:
# -> 1147             executor.execute_mapping()
#    1148             self._pacman_provenance.extract_provenance(executor)
#    1149             return executor
#
# ~/sPyNNakerGit/PACMAN/pacman/executor/pacman_algorithm_executor.py in execute_mapping(self)
#     634         if self._do_direct_injection:
#     635             with injection_context(self._internal_type_mapping):
# --> 636                 self.__execute_mapping()
#     637         else:
#     638             self.__execute_mapping()
#
# ~/sPyNNakerGit/PACMAN/pacman/executor/pacman_algorithm_executor.py in __execute_mapping(self)
#     650
#     651             # Execute the algorithm
# --> 652             results = algorithm.call(self._internal_type_mapping)
#     653
#     654             if self._provenance_path:
#
# ~/sPyNNakerGit/PACMAN/pacman/executor/algorithm_classes/abstract_python_algorithm.py in call(self, inputs)
#      75
#      76         # Run the algorithm and get the results
# ---> 77         results = self.call_python(method_inputs)
#      78
#      79         if results is not None and not isinstance(results, tuple):
#
# ~/sPyNNakerGit/PACMAN/pacman/executor/algorithm_classes/python_class_algorithm.py in call_python(self, inputs)
#      87             method = getattr(instance, self._python_method)
#      88         try:
# ---> 89             return method(**inputs)
#      90         except Exception:
#      91             method = "__call__"
#
# ~/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/overridden_pacman_functions/spynnaker_data_specification_writer.py in __call__(self, placements, hostname, report_default_directory, write_text_specs, machine, data_n_timesteps, graph_mapper)
#      47             placements, hostname, report_default_directory, write_text_specs,
#      48             machine, data_n_timesteps, graph_mapper,
# ---> 49             placement_order)
#
# ~/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/interface_functions/graph_data_specification_writer.py in __call__(self, placements, hostname, report_default_directory, write_text_specs, machine, data_n_timesteps, graph_mapper, placement_order)
#     105                     placement.vertex)
#     106                 generated = self.__generate_data_spec_for_vertices(
# --> 107                     placement, associated_vertex, targets, data_n_timesteps)
#     108                 if generated and isinstance(
#     109                         associated_vertex, AbstractRewritesDataSpecification):
#
# ~/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/interface_functions/graph_data_specification_writer.py in __generate_data_spec_for_vertices(self, pl, vertex, targets, data_n_timesteps)
#     136
#     137             # generate the DSG file
# --> 138             vertex.generate_data_specification(spec, pl)
#     139
#     140             # Check the memory usage
#
# ~/sPyNNakerGit/PACMAN/pacman/executor/injection_decorator.py in wrapper(obj, *args, **kwargs)
#     142                             arg, wrapped_method.__name__, obj.__class__))
#     143                 new_args[arg] = _injectables[arg_type]
# --> 144             return wrapped_method(obj, *args, **new_args)
#     145         return wrapper
#     146     return wrap
#
# ~/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/models/neuron/abstract_population_vertex.py in generate_data_specification(self, spec, placement, machine_time_step, time_scale_factor, graph_mapper, application_graph, machine_graph, routing_info, data_n_time_steps)
#     484         # Write the neuron parameters
#     485         self._write_neuron_parameters(
# --> 486             spec, key, vertex_slice, machine_time_step, time_scale_factor)
#     487
#     488         # write profile data
#
# ~/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/models/neuron/abstract_population_vertex.py in _write_neuron_parameters(self, spec, key, vertex_slice, machine_time_step, time_scale_factor)
#     389         # Write the neuron parameters
#     390         neuron_data = self.__neuron_impl.get_data(
# --> 391             self._parameters, self._state_variables, vertex_slice)
#     392         spec.write_array(neuron_data)
#     393
#
# ~/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/models/neuron/implementations/neuron_impl_standard.py in get_data(self, parameters, state_variables, vertex_slice)
#     169         return numpy.concatenate([
#     170             component.get_data(parameters, state_variables, vertex_slice)
# --> 171             for component in self.__components
#     172         ])
#     173
#
# ~/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/models/neuron/implementations/neuron_impl_standard.py in <listcomp>(.0)
#     169         return numpy.concatenate([
#     170             component.get_data(parameters, state_variables, vertex_slice)
# --> 171             for component in self.__components
#     172         ])
#     173
#
# ~/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/models/neuron/neuron_models/abstract_neuron_model.py in get_data(self, parameters, state_variables, vertex_slice)
#      80     def get_data(self, parameters, state_variables, vertex_slice):
#      81         super_data = super(AbstractNeuronModel, self).get_data(
# ---> 82             parameters, state_variables, vertex_slice)
#      83         values = self.get_global_values()
#      84         global_data = self.__global_struct.get_data(values)
#
# ~/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/models/neuron/implementations/abstract_standard_neuron_component.py in get_data(self, parameters, state_variables, vertex_slice)
#     114         values = self.get_values(parameters, state_variables, vertex_slice)
#     115         return self.struct.get_data(
# --> 116             values, vertex_slice.lo_atom, vertex_slice.n_atoms)
#     117
#     118     @abstractmethod
#
# ~/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/models/neuron/implementations/struct.py in get_data(self, values, offset, array_size)
#     101                         data_value = [convert_to(v, data_type) for v in values]
#     102                     else:
# --> 103                         data_value = convert_to(value, data_type)
#     104                     data["f" + str(i)][
#     105                         start - offset:end - offset] = data_value
#
# ~/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/utilities/utility_calls.py in convert_to(value, data_type)
#     103     :rtype: ~numpy.ndarray(int32)
#     104     """
# --> 105     return numpy.round(data_type.encode_as_int(value)).astype(
#     106         data_type.struct_encoding)
#     107
#
# ~/sPyNNakerGit/DataSpecification/data_specification/enums/data_type.py in encode_as_int(self, value)
#     389         """
#     390         if self._apply_scale:
# --> 391             if not (self._min <= value <= self._max):
#     392                 raise ValueError(
#     393                     "value {:f} cannot be converted to {:s}: out of range"
#
# TypeError: argument must be an integer

# %%
''' On simulation completion, extract the data off the spinnaker machine
memory'''


# extracting the spike time data
# spikesourcepattern_TCR = spike_source_periodic_TCR.get_data("spikes")
# spikesourcepattern_IN = spike_source_periodic_IN.get_data("spikes")
spikesourcepattern_TCR = spike_source_TCR.get_data("spikes")
spikesourcepattern_IN = spike_source_IN.get_data("spikes")
TCR_spikes = TCR_pop.get_data("spikes")
IN_spikes = IN_pop.get_data("spikes")
TRN_spikes = TRN_pop.get_data("spikes")

# extracting the membrane potential data (in millivolts)
TCR_membrane_volt = TCR_pop.get_data("v")
IN_membrane_volt = IN_pop.get_data("v")
TRN_membrane_volt = TRN_pop.get_data("v")

# print TCR_membrane_volt.segments[0].analogsignals
TCR_gsyn_e = TCR_pop.get_data("gsyn_exc")
IN_gsyn_e = IN_pop.get_data("gsyn_exc")
TRN_gsyn_e = TRN_pop.get_data("gsyn_exc")

TCR_gsyn_i = TCR_pop.get_data("gsyn_inh")
IN_gsyn_i = IN_pop.get_data("gsyn_inh")
TRN_gsyn_i = TRN_pop.get_data("gsyn_inh")

# %%
print_irregularity()

# %%
print_synchrony()

# %%
print(get_mean_rate(NumCellsTCR, TCR_spikes)*1000)
print(get_mean_rate(NumCellsIN, IN_spikes)*1000)
print(get_mean_rate(NumCellsTRN, TRN_spikes)*1000)

# %%
''' Plotting '''

Figure(
    # raster plot of the presynaptic neuron spike times
    Panel(TCR_spikes.segments[0].spiketrains, xlabel="Time/ms", xticks=True, ylabel="TCR Spikes Plots for TotalDuration",
          yticks=True, markersize=0.5, xlim=(1, TotalDuration), color = 'red'),
    Panel(IN_spikes.segments[0].spiketrains, xlabel="Time/ms", xticks=True, ylabel="IN Spikes Plots for TotalDuration",
          yticks=True, markersize=0.5, xlim=(1, TotalDuration), color = 'red'),
    Panel(TRN_spikes.segments[0].spiketrains, xlabel="Time/ms", xticks=True, ylabel="TRN Spikes Plots for TotalDuration",
          yticks=True, markersize=0.5, xlim=(1, TotalDuration), color = 'red'),
    Panel(TCR_membrane_volt.segments[0].filter(name="v")[0], xlabel="Time/ms", xticks=True, ylabel="TCR Spikes Plots for TotalDuration",
          yticks=True, markersize=0.5, xlim=(100, 400), legend=False),
    Panel(IN_membrane_volt.segments[0].filter(name="v")[0], xlabel="Time/ms", xticks=True, ylabel="IN Spikes Plots for TotalDuration",
          yticks=True, markersize=0.5, xlim=(100, 400), legend=False),
    Panel(TRN_membrane_volt.segments[0].filter(name="v")[0], xlabel="Time/ms", xticks=True, ylabel="TRN Spikes Plots for TotalDuration",
          yticks=True, markersize=0.5, xlim=(100, 400), legend=False),
)
plt.savefig("Effect of I_DC on periodic input.png")
plt.show()

# %%
p.end()
